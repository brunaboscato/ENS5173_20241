# %% [markdown]
# # Aula 03 - PYTHON

# %% [markdown]
# Nesta aula veremos:
# 1. Numpy arrays e Pandas Dataframes
# 2. Open and Export files
# 3. Conditional Statements
# 4. Loops em Python
# 5. Functions- def

# %% [markdown]
# ### 1.1 Numpy arrays

# %%
import numpy as np 

# Criando um vetor de dados aleatórios
data = np.random.rand(1000,2)

# Verificando o tamanho do vetor
print(data.shape)
print(np.size(data))

# Print de uma amostra dos dados
print(data[0:10]) # pedindo para mostrar apenas as 10 primeiras linhas
print(data[0:10].shape) # formato
# Out:
# (1000, 2)
# 2000
# [[0.59878145 0.47759237]
#  [0.8968035  0.00725082]
#  [0.99999191 0.53029432]
#  [0.36630256 0.61241759]
#  [0.50977513 0.73403123]
#  [0.68770676 0.65532053]
#  [0.68279919 0.31125272]
#  [0.43413823 0.19081796]
#  [0.21222413 0.15393004]
#  [0.736514   0.35092624]]
# (10, 2)

# %% [markdown]
# Monte Carlo é uma técnica computacional utilizada para resolver problemas através de métodos estatísticos e da simulação de eventos aleatórios.

# %%
# Usando Monte-Carlo
dataMax = 1000
dataMin = 10
data = (dataMax - dataMin)*data + dataMin
print(data[0:10])
# estipulou um dataMax e dataMin, multiplicou os dados pela diferença deles e depois somou o dataMin nos dados
# Out:
# [[602.79363444 482.8164466 ]
#  [897.83546277  17.17831562]
#  [999.99198664 534.99137552]
#  [372.6395324  616.29341352]
#  [514.6773797  736.69091884]
#  [690.82969243 658.76732757]
#  [685.97120245 318.14018977]
#  [439.79684703 198.90977744]
#  [220.10189151 162.39073784]
#  [739.14885763 357.41697566]]

# %%
# Plotando os dados
import matplotlib.pyplot as plt

fig, ax = plt.subplots(3)
ax[0].plot(data) # plotando os dados completos
ax[1].plot(data[:,0]) # plotando os dados da primeira coluna
ax[2].plot(data[:,1]) # plotando os dados da segunda coluna
print(type(data))
# Out:
# <class 'numpy.ndarray'>

# %%
# Criando um dado 2D 
data3d = np.sin(np.random.rand(1000,1000)) # criando dados aleatórios de 1000 linhas e 1000 colunas, usando o seno 
print(data3d)
# Out:
# [[0.2065861  0.6524316  0.80173549 ... 0.80001605 0.33483505 0.71620442]
#  [0.59417286 0.33541263 0.81452798 ... 0.65725065 0.69775443 0.34109714]
#  [0.20793037 0.34648055 0.66895783 ... 0.67026379 0.56072772 0.72432573]
#  ...
#  [0.60252087 0.27011569 0.06008568 ... 0.00624825 0.36183226 0.2164755 ]
#  [0.73113895 0.79297358 0.54003882 ... 0.82916841 0.54910196 0.309033  ]
#  [0.44001323 0.32251759 0.38410389 ... 0.77822558 0.00736939 0.59038659]]

# %%
# Plotando um dado 3D
fig2, ax2 = plt.subplots()
ax2.pcolor(data3d)
# criando um gráfico de pseudocolor na fig2 usando os dados contidos na matriz data3d, e os eixos desse gráfico são especificados por ax2

# %%
# Criando vertor temporal
dtime = np.arange(np.datetime64("2022-01-01"), np.datetime64("2023-01-01"), np.timedelta64(1, "h")) # criando um array de datas e horas começando em "2022-01-01", terminando em "2023-01-01", com um intervalo de 1 hora entre cada elemento.
print(dtime[1:10])
print(dtime.shape)
print(type(dtime))
# Out:
# ['2022-01-01T01' '2022-01-01T02' '2022-01-01T03' '2022-01-01T04'
#  '2022-01-01T05' '2022-01-01T06' '2022-01-01T07' '2022-01-01T08'
#  '2022-01-01T09']
# (8760,)
# <class 'numpy.ndarray'>

# %% [markdown]
# ### PANDAS

# %%
import pandas as pd

# Criando um dataframe
df = pd.DataFrame()

# %% [markdown]
# DataFrame é uma estrutura de dados bidimensional semelhante a uma tabela.

# %%
# Monstrando um dataframe
df['datetime'] = dtime

# %%
# Criando uma coluna random dentro do dataframe df
df['random'] = np.random.rand(df.shape[0])

# %%
df['random'][1:10] # uma série contendo os elementos da coluna 'random' do DataFrame df, das linhas 1 a 9
# Out:
# 1    0.117730
# 2    0.850466
# 3    0.774992
# 4    0.191666
# 5    0.998120
# 6    0.506969
# 7    0.653586
# 8    0.150500
# 9    0.242827
# Name: random, dtype: float64

# %%
# Indexação
df.iloc[:,0]
# Out:
# 0      2022-01-01 00:00:00
# 1      2022-01-01 01:00:00
# 2      2022-01-01 02:00:00
# 3      2022-01-01 03:00:00
# 4      2022-01-01 04:00:00
#                ...
# 8755   2022-12-31 19:00:00
# 8756   2022-12-31 20:00:00
# 8757   2022-12-31 21:00:00
# 8758   2022-12-31 22:00:00
# 8759   2022-12-31 23:00:00
# Name: datetime, Length: 8760, dtype: datetime64[s]

# %% [markdown]
# Indexação é o processo de acessar elementos em uma sequência.

# %%
# Colocando o datetime como index
df = df.set_index(df['datetime']) # o índice do DataFrame df será definido como a coluna 'datetime'
df
# Out:
#                                datetime    random
# datetime
# 2022-01-01 00:00:00 2022-01-01 00:00:00  0.326008
# 2022-01-01 01:00:00 2022-01-01 01:00:00  0.117730
# 2022-01-01 02:00:00 2022-01-01 02:00:00  0.850466
# 2022-01-01 03:00:00 2022-01-01 03:00:00  0.774992
# 2022-01-01 04:00:00 2022-01-01 04:00:00  0.191666
# ...                                 ...       ...
# 2022-12-31 19:00:00 2022-12-31 19:00:00  0.433201
# 2022-12-31 20:00:00 2022-12-31 20:00:00  0.280116
# 2022-12-31 21:00:00 2022-12-31 21:00:00  0.955072
# 2022-12-31 22:00:00 2022-12-31 22:00:00  0.978599
# 2022-12-31 23:00:00 2022-12-31 23:00:00  0.064108
#
# [8760 rows x 2 columns]

# %%
# Criando colunas com ano, mês e dia
df['year'] = df.index.year
df['month'] = df.index.month
df['day'] = df.index.day

# %%
tt = np.arange(0,df.shape[0],1) # criando um array "tt" usando a função np.arange(), que gera valores de 0 até o número de linhas no DataFrame df, com um passo de 1.
print(tt.shape)
df['sazonal'] = (np.cos(tt/(360*4))) # usando a função np.cos() para calcular o cosseno de cada valor em tt dividido por (360*4)
df['timeSeries'] = 10*df['sazonal']+df['random'] # calculando a série temporal completa combinando a componente sazonal (multiplicada por 10) com uma série aleatória já existente no DataFrame df como 'random'
#df['sazonal'].plot()
df['timeSeries'].plot(color='red') # plotando a série temporal completa "timeSeries" usando a função plot() do pandas, com a cor vermelha
# Out:
# (8760,)
# <Axes: xlabel='datetime'>

# %%
df # estrutura fornecida pela biblioteca pandas
# Out:
#                                datetime    random  year  month  day   sazonal  \
# datetime
# 2022-01-01 00:00:00 2022-01-01 00:00:00  0.326008  2022      1    1  1.000000
# 2022-01-01 01:00:00 2022-01-01 01:00:00  0.117730  2022      1    1  1.000000
# 2022-01-01 02:00:00 2022-01-01 02:00:00  0.850466  2022      1    1  0.999999
# 2022-01-01 03:00:00 2022-01-01 03:00:00  0.774992  2022      1    1  0.999998
# 2022-01-01 04:00:00 2022-01-01 04:00:00  0.191666  2022      1    1  0.999996
# ...                                 ...       ...   ...    ...  ...       ...
# 2022-12-31 19:00:00 2022-12-31 19:00:00  0.433201  2022     12   31  0.979401
# 2022-12-31 20:00:00 2022-12-31 20:00:00  0.280116  2022     12   31  0.979541
# 2022-12-31 21:00:00 2022-12-31 21:00:00  0.955072  2022     12   31  0.979680
# 2022-12-31 22:00:00 2022-12-31 22:00:00  0.978599  2022     12   31  0.979819
# 2022-12-31 23:00:00 2022-12-31 23:00:00  0.064108  2022     12   31  0.979958
#
#                      timeSeries
# datetime
# 2022-01-01 00:00:00   10.326008
# 2022-01-01 01:00:00   10.117727
# 2022-01-01 02:00:00   10.850456
# 2022-01-01 03:00:00   10.774970
# 2022-01-01 04:00:00   10.191627
# ...                         ...
# 2022-12-31 19:00:00   10.227208
# 2022-12-31 20:00:00   10.075523
# 2022-12-31 21:00:00   10.751874
# 2022-12-31 22:00:00   10.776792
# 2022-12-31 23:00:00    9.863686
#
# [8760 rows x 7 columns]

# %%
# Salvar meu dataframe

df.to_csv(r'C:\Users\bruna\OneDrive\Documentos\UFSC\Controle de Poluicao Atmosferica\ENS5173_20241\Dados\noise_2022.csv')
#  salvando o DataFrame em um arquivo CSV usando o método to_csv() do pandas

# %% [markdown]
# Este método converte o DataFrame em um arquivo CSV e o salva no caminho especificado.

# %%
# Criando uma função
def noiseCreation(path, year): # definindo uma função chamada "noiseCreation"
    """Esta função cria um ruido com sazonalidade.
    Inputs:
        path = asdasdas
        year = asdasdasdas

    Criado por Leonardo
    """
    
    # Criando um dataframe
    df = pd.DataFrame()
    
    # Criando vertor temporal
    dtime = np.arange(np.datetime64(str(year)+"-01-01"), np.datetime64(str(year+1)+"-01-01"), np.timedelta64(1, "h"))
    
    # Monstrando um dataframe
    df['datetime'] = dtime
        
    # Datetime como index do dataframe
    df = df.set_index(df['datetime'])
    
    # Criando colunas com ano, mês e dia
    df['year'] = df.index.year
    df['month'] = df.index.month
    df['day'] = df.index.day
    
    # Crio uma coluna random
    df['random'] = np.random.rand(df.shape[0])
    
    # Adicionar sazonalidade
    tt = np.arange(0,df.shape[0],1)
    print(tt.shape)
    df['sazonal'] = (np.cos(tt/(360*4))) # sazonalidade é adicionada à série temporal através da coluna "sazonal"
    df['timeSeries'] = 10*df['sazonal']+df['random']
    #df['sazonal'].plot()
    df['timeSeries'].plot(color='red') # plotando a série temporal resultante com a cor vermelha
    df.to_csv(path+'/noise_'+str(year)+'.csv') # salvando o DataFrame em um arquivo CSV com o nome "noise_ano.csv" no caminho especificado
    
    return df

# %%
# definindo uma variável chamada path, que contém o caminho para o diretório onde os arquivos CSV serão salvos
path = 'C:/Users/bruna/OneDrive/Documentos/UFSC/Controle de Poluicao Atmosferica/ENS5173_20241/Dados' 
df2 = noiseCreation(path,2050) # caminho para o diretório onde os arquivos CSV serão salvos (definido pela variável path), e o ano de 2050
# Out:
# (8760,)

# %%
# Primeira opção de loop
for ii in range(2002,2010): # valor de ii será atualizado em cada iteração, começando com 2002 e terminando com 2009
    print(ii)
    df = noiseCreation(path,ii)
# Out:
# 2002
# (8760,)
# 2003
# (8760,)
# 2004
# (8784,)
# 2005
# (8760,)
# 2006
# (8760,)
# 2007
# (8760,)
# 2008
# (8784,)
# 2009
# (8760,)

# %%
df
# Out:
#                                datetime  year  month  day    random   sazonal  \
# datetime
# 2009-01-01 00:00:00 2009-01-01 00:00:00  2009      1    1  0.474435  1.000000
# 2009-01-01 01:00:00 2009-01-01 01:00:00  2009      1    1  0.093657  1.000000
# 2009-01-01 02:00:00 2009-01-01 02:00:00  2009      1    1  0.960930  0.999999
# 2009-01-01 03:00:00 2009-01-01 03:00:00  2009      1    1  0.442661  0.999998
# 2009-01-01 04:00:00 2009-01-01 04:00:00  2009      1    1  0.576401  0.999996
# ...                                 ...   ...    ...  ...       ...       ...
# 2009-12-31 19:00:00 2009-12-31 19:00:00  2009     12   31  0.112787  0.979401
# 2009-12-31 20:00:00 2009-12-31 20:00:00  2009     12   31  0.483468  0.979541
# 2009-12-31 21:00:00 2009-12-31 21:00:00  2009     12   31  0.826915  0.979680
# 2009-12-31 22:00:00 2009-12-31 22:00:00  2009     12   31  0.476076  0.979819
# 2009-12-31 23:00:00 2009-12-31 23:00:00  2009     12   31  0.023809  0.979958
#
#                      timeSeries
# datetime
# 2009-01-01 00:00:00   10.474435
# 2009-01-01 01:00:00   10.093654
# 2009-01-01 02:00:00   10.960920
# 2009-01-01 03:00:00   10.442640
# 2009-01-01 04:00:00   10.576362
# ...                         ...
# 2009-12-31 19:00:00    9.906794
# 2009-12-31 20:00:00   10.278875
# 2009-12-31 21:00:00   10.623718
# 2009-12-31 22:00:00   10.274269
# 2009-12-31 23:00:00    9.823388
#
# [8760 rows x 7 columns]

# %%
anos = [2001,2030,2032,2053,2060] # lista chamada anos

for ano in anos: # vai iterar sobre cada elemento da lista anos usando um loop "for"
    print(ano)
    if ano > 2030:
        df = noiseCreation(path,ano)

# vai passar em cada ano na lista anos 
# imprimirá o ano atual e, se o ano for maior que 2030, chamará a função noiseCreation, passando o caminho (path) e o ano como argumentos
# o DataFrame resultante da função noiseCreation será atribuído à variável df
# Out:
# 2001
# 2030
# 2032
# (8784,)
# 2053
# (8760,)
# 2060
# (8784,)

# %%
import os 
files = os.listdir(path) # listar arquivos no diretório especificado por "path"
print(files)

# lista para armazenar todos os dados dos arquivos CSV
allData = [] # criando uma lista 
for file in files: # iterar sobre cada arquivo
    if file.endswith('.csv'): # verificar se o arquivo é um arquivo CSV
        print(file)
        data = pd.read_csv(path+'/'+file) # ler o arquivo CSV e adicionar os dados à lista 'allData'
        allData.append(data)
# Out:
# ['noise_2002.csv', 'noise_2003.csv', 'noise_2004.csv', 'noise_2005.csv', 'noise_2006.csv', 'noise_2007.csv', 'noise_2008.csv', 'noise_2009.csv', 'noise_2022.csv', 'noise_2032.csv', 'noise_2050.csv', 'noise_2053.csv', 'noise_2060.csv']
# noise_2002.csv
# noise_2003.csv
# noise_2004.csv
# noise_2005.csv
# noise_2006.csv
# noise_2007.csv
# noise_2008.csv
# noise_2009.csv
# noise_2022.csv
# noise_2032.csv
# noise_2050.csv
# noise_2053.csv
# noise_2060.csv

# %%
allDataDf = pd.concat(allData) # concatenando todos os DataFrames presentes na lista "allData"

# %%
allDataDf # DataFrame resultante da concatenação de todos os DataFrames presentes na lista "allData"
# Out:
#                  datetime           datetime.1  year  month  day    random  \
# 0     2002-01-01 00:00:00  2002-01-01 00:00:00  2002      1    1  0.712341
# 1     2002-01-01 01:00:00  2002-01-01 01:00:00  2002      1    1  0.737066
# 2     2002-01-01 02:00:00  2002-01-01 02:00:00  2002      1    1  0.366816
# 3     2002-01-01 03:00:00  2002-01-01 03:00:00  2002      1    1  0.642373
# 4     2002-01-01 04:00:00  2002-01-01 04:00:00  2002      1    1  0.832337
# ...                   ...                  ...   ...    ...  ...       ...
# 8779  2060-12-31 19:00:00  2060-12-31 19:00:00  2060     12   31  0.427954
# 8780  2060-12-31 20:00:00  2060-12-31 20:00:00  2060     12   31  0.299805
# 8781  2060-12-31 21:00:00  2060-12-31 21:00:00  2060     12   31  0.037917
# 8782  2060-12-31 22:00:00  2060-12-31 22:00:00  2060     12   31  0.432192
# 8783  2060-12-31 23:00:00  2060-12-31 23:00:00  2060     12   31  0.251086
#
#        sazonal  timeSeries
# 0     1.000000   10.712341
# 1     1.000000   10.737064
# 2     0.999999   10.366807
# 3     0.999998   10.642351
# 4     0.999996   10.832299
# ...        ...         ...
# 8779  0.982630   10.254254
# 8780  0.982759   10.127391
# 8781  0.982887    9.866785
# 8782  0.983014   10.262337
# 8783  0.983142   10.082503
#
# [113976 rows x 8 columns]

# %%
plt.plot(allDataDf['datetime'],allDataDf['timeSeries']) #  plotando um gráfico usando os dados contidos no DataFrame "allDataDf"
